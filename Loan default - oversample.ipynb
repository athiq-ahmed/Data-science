# %%
from IPython.display import Image
Image(filename=r'C:\Users\athiq.ahmed\Desktop\Oversample image.jpg',width = 450)

# %%
import pandas as pd
data_dic = pd.read_excel('https://query.data.world/s/4JMEhvJkB9IrzJp59E1lbhjk2utJYV')

# %%
data_dic
# data_dic.head()
# Out:
#             LoanStatNew                                        Description
# 0        acc_now_delinq  The number of accounts on which the borrower i...
# 1  acc_open_past_24mths         Number of trades opened in past 24 months.
# 2            addr_state  The state provided by the borrower in the loan...
# 3              all_util              Balance to credit limit on all trades
# 4            annual_inc  The self-reported annual income provided by th...

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/G5cpPMYTslJnT2M_rSla0eRmGxTzJy',low_memory=False)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.shape
# Out:
# (96782, 1)

# %%
df.dtypes

# %%
df.describe()
# Out:
#        Notes offered by Prospectus (https://www.lendingclub.com/info/prospectus.action)
# count                                                 357
# unique                                                 84
# top                                                    38
# freq                                                   15
